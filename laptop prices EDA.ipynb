# %%
# libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# dataset
data = pd.read_csv(r"C:\project\archive (6).zip")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1275 entries, 0 to 1274
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Company               1275 non-null   object
#  1   Product               1275 non-null   object
#  2   TypeName              1275 non-null   object
#  3   Inches                1275 non-null   float64
#  4   Ram                   1275 non-null   int64
#  5   OS                    1275 non-null   object
#  6   Weight                1275 non-null   float64
#  7   Price_euros           1275 non-null   float64
#  8   Screen                1275 non-null   object
#  9   ScreenW               1275 non-null   int64
#  10  ScreenH               1275 non-null   int64
#  11  Touchscreen           1275 non-null   object
#  12  IPSpanel              1275 non-null   object
#  13  RetinaDisplay         1275 non-null   object
#  14  CPU_company           1275 non-null   object
# ...

# %%
data.head()
# Out:
#   Company      Product   TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 0   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1339.69
# 1   Apple  Macbook Air  Ultrabook    13.3    8  macOS    1.34       898.94
# 2      HP       250 G6   Notebook    15.6    8  No OS    1.86       575.00
# 3   Apple  MacBook Pro  Ultrabook    15.4   16  macOS    1.83      2537.45
# 4   Apple  MacBook Pro  Ultrabook    13.3    8  macOS    1.37      1803.60
#
#      Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq      CPU_model  \
# 0  Standard     2560  ...            Yes       Intel      2.3        Core i5
# 1  Standard     1440  ...             No       Intel      1.8        Core i5
# 2   Full HD     1920  ...             No       Intel      2.5  Core i5 7200U
# 3  Standard     2880  ...            Yes       Intel      2.7        Core i7
# 4  Standard     2560  ...            Yes       Intel      3.1        Core i5
#
# ...

# %%
data.shape
# Out:
# (1275, 23)

# %%
data.isnull()
# Out:
#       Company  Product  TypeName  Inches    Ram     OS  Weight  Price_euros  \
# 0       False    False     False   False  False  False   False        False
# 1       False    False     False   False  False  False   False        False
# 2       False    False     False   False  False  False   False        False
# 3       False    False     False   False  False  False   False        False
# 4       False    False     False   False  False  False   False        False
# ...       ...      ...       ...     ...    ...    ...     ...          ...
# 1270    False    False     False   False  False  False   False        False
# 1271    False    False     False   False  False  False   False        False
# 1272    False    False     False   False  False  False   False        False
# 1273    False    False     False   False  False  False   False        False
# 1274    False    False     False   False  False  False   False        False
#
# ...

# %%
data.tail()
# Out:
#      Company                              Product            TypeName  Inches  \
# 1270  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1271  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1272  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1274    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#       Ram          OS  Weight  Price_euros    Screen  ScreenW  ...  \
# 1270    4  Windows 10    1.80        638.0   Full HD     1920  ...
# 1271   16  Windows 10    1.30       1499.0  Quad HD+     3200  ...
# 1272    2  Windows 10    1.50        229.0  Standard     1366  ...
# 1273    6  Windows 10    2.19        764.0  Standard     1366  ...
# 1274    4  Windows 10    2.20        369.0  Standard     1366  ...
#
#       RetinaDisplay CPU_company CPU_freq                CPU_model  \
# ...

# %%
data[data.index == 1273]
# Out:
#      Company                              Product  TypeName  Inches  Ram  \
# 1273      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon  Notebook    15.6    6
#
#               OS  Weight  Price_euros    Screen  ScreenW  ...  RetinaDisplay  \
# 1273  Windows 10    2.19        764.0  Standard     1366  ...             No
#
#      CPU_company CPU_freq      CPU_model PrimaryStorage  SecondaryStorage  \
# 1273       Intel      2.5  Core i7 6500U           1024                 0
#
#      PrimaryStorageType  SecondaryStorageType  GPU_company       GPU_model
# 1273                HDD                    No          AMD  Radeon R5 M330
#
# [1 rows x 23 columns]

# %%
data.iloc[53:103]
# Out:
#        Company                                       Product  \
# 53          HP                                   ProBook 430
# 54        Acer                                      Aspire 3
# 55        Dell                                 Inspiron 3576
# 56          HP       15-bs002nv (i3-6006U/4GB/128GB/FHD/W10)
# 57        Asus                                  VivoBook Max
# 58         MSI                                    GS73VR 7RG
# 59        Asus  X541UA-DM1897 (i3-6006U/4GB/256GB/FHD/Linux)
# 60        Dell                                 Inspiron 5770
# 61        Dell                                   Vostro 5471
# 62      Lenovo                            IdeaPad 520S-14IKB
# 63        Asus   UX410UA-GV350T (i5-8250U/8GB/256GB/FHD/W10)
# 64          HP                                        250 G6
# 65        Asus                                   ZenBook Pro
# 66          HP                                        250 G6
# ...

# %%
data.columns
# Out:
# Index(['Company', 'Product', 'TypeName', 'Inches', 'Ram', 'OS', 'Weight',
#        'Price_euros', 'Screen', 'ScreenW', 'ScreenH', 'Touchscreen',
#        'IPSpanel', 'RetinaDisplay', 'CPU_company', 'CPU_freq', 'CPU_model',
#        'PrimaryStorage', 'SecondaryStorage', 'PrimaryStorageType',
#        'SecondaryStorageType', 'GPU_company', 'GPU_model'],
#       dtype='object')

# %%
data['Company'].value_counts()
# Out:
# Company
# Dell         291
# Lenovo       289
# HP           268
# Asus         152
# Acer         101
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: count, dtype: int64

# %%
plt.figsize = (10,30)
sns.histplot(data ,y="Company",x="CPU_company")
# Out:
# <Axes: xlabel='CPU_company', ylabel='Company'>

# %%
plt.figsize = (1000,1000)
sns.displot(data, y="OS",x="Weight")

# %%
plt.figsize = (10,30)
sns.relplot(data ,y="Company", x="Screen")

# %%
plt.figsize = (100,100)
sns.barplot(data , y="TypeName", x="Inches")
# Out:
# <Axes: xlabel='Inches', ylabel='TypeName'>

# %%
sns.lmplot(y="ScreenW", x="CPU_freq", data=data)

# %%
sns.relplot(data=data, y="Company", x="Inches", kind="line")

# %%
plt.figsize = (1000,1000)
sns.catplot(data=data, x="PrimaryStorageType", y="PrimaryStorage")

# %%
top_5_weight = data.nlargest(5, 'Weight')
print("\nTop 5 Weight Laptops:")
print(top_5_weight)
# Out:
# Top 5 Weight Laptops:
#      Company             Product TypeName  Inches  Ram          OS  Weight  \
# 238     Asus   ROG G703VI-E5062T   Gaming    17.3   32  Windows 10     4.7
# 577   Lenovo  IdeaPad Y910-17ISK   Gaming    17.3   32  Windows 10     4.6
# 1048  Lenovo  IdeaPad Y900-17ISK   Gaming    17.3   16  Windows 10     4.6
# 1081  Lenovo  IdeaPad Y900-17ISK   Gaming    17.3   32  Windows 10     4.6
# 1116  Lenovo  IdeaPad Y900-17ISK   Gaming    17.3   16  Windows 10     4.6
#
#       Price_euros   Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq  \
# 238       3890.00  Full HD     1920  ...             No       Intel      2.9
# 577       2663.00  Full HD     1920  ...             No       Intel      2.7
# 1048      2289.99  Full HD     1920  ...             No       Intel      2.6
# 1081      3240.00  Full HD     1920  ...             No       Intel      2.7
# 1116      2749.99  Full HD     1920  ...             No       Intel      2.7
#
# ...

# %%
top_5_price = data.nlargest(5, 'Price_euros')
print("\nTop 5 Price Laptops:")
print(top_5_price)
# Out:
# Top 5 Price Laptops:
#      Company       Product     TypeName  Inches  Ram          OS  Weight  \
# 196    Razer     Blade Pro       Gaming    17.3   32  Windows 10    3.49
# 830    Razer     Blade Pro       Gaming    17.3   32  Windows 10    3.49
# 610   Lenovo  Thinkpad P51     Notebook    15.6   32  Windows 10    2.50
# 749       HP      Zbook 17  Workstation    17.3   16   Windows 7    3.00
# 1066    Asus    ROG G701VO       Gaming    17.3   64  Windows 10    3.58
#
#       Price_euros       Screen  ScreenW  ...  RetinaDisplay CPU_company  \
# 196        6099.0  4K Ultra HD     3840  ...             No       Intel
# 830        5499.0  4K Ultra HD     3840  ...             No       Intel
# 610        4899.0  4K Ultra HD     3840  ...             No       Intel
# 749        4389.0      Full HD     1920  ...             No       Intel
# 1066       3975.0      Full HD     1920  ...             No       Intel
#
#      CPU_freq         CPU_model PrimaryStorage  SecondaryStorage  \
# ...

# %%
# Set the aesthetic style of the plots
sns.set(style="whitegrid")

plt.figure(figsize=(10, 5))
sns.histplot(data=data, x='Price_euros', hue='Company', bins=10, kde=True, multiple="stack")

# Add labels
plt.xlabel('Price (Euros)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
# Encode categorical variables to numeric for regplot
data['Product'] = data['Product'].astype('category').cat.codes
data['CPU_model'] = data['CPU_model'].astype('category').cat.codes

# Create the regression plot
plt.figure(figsize=(10, 10))
sns.regplot(y='Product', x='Price_euros', data=data)
sns.regplot(y='CPU_model', x='Price_euros', data=data, color='orange')

# Adding labels and title
plt.xlabel('Product and CPU Model')
plt.ylabel('Price in Euros')
plt.xticks(ticks=data['Product'].unique(), labels=data['Product'].unique(), rotation=45)
plt.grid(True)
plt.show()

# %%
data.head(50)
# Out:
#    Company  Product            TypeName  Inches  Ram          OS  Weight  \
# 0    Apple      300           Ultrabook    13.3    8       macOS    1.37
# 1    Apple      301           Ultrabook    13.3    8       macOS    1.34
# 2       HP       50            Notebook    15.6    8       No OS    1.86
# 3    Apple      300           Ultrabook    15.4   16       macOS    1.83
# 4    Apple      300           Ultrabook    13.3    8       macOS    1.37
# 5     Acer       58            Notebook    15.6    4  Windows 10    2.10
# 6    Apple      300           Ultrabook    15.4   16    Mac OS X    2.04
# 7    Apple      301           Ultrabook    13.3    8       macOS    1.34
# 8     Asus      608           Ultrabook    14.0   16  Windows 10    1.30
# 9     Acer      430           Ultrabook    14.0    8  Windows 10    1.60
# 10      HP       50            Notebook    15.6    4       No OS    1.86
# 11      HP       50            Notebook    15.6    4       No OS    1.86
# ...

# %%
data.tail(50)
# Out:
#      Company  Product            TypeName  Inches  Ram          OS  Weight  \
# 1225    Asus      553            Notebook    15.6    4  Windows 10    2.65
# 1226    Dell      576           Ultrabook    13.3    8  Windows 10    1.29
# 1227    Dell      547            Notebook    15.6    4       Linux    2.18
# 1228  Lenovo      225              Gaming    15.6   16  Windows 10    2.60
# 1229     MSI      161              Gaming    15.6    8  Windows 10    2.20
# 1230  Lenovo      474             Netbook    12.5   16  Windows 10    1.30
# 1231   Razer       85              Gaming    14.0   16  Windows 10    1.95
# 1232    Dell      239            Notebook    15.6    8  Windows 10    2.30
# 1233     MSI      154              Gaming    17.3   16  Windows 10    2.70
# 1234   Apple      299           Ultrabook    11.6    4    Mac OS X    1.08
# 1235      HP       23            Notebook    15.6    4  Windows 10    2.10
# ...

# %%
data.iloc[5:50]
# Out:
#    Company  Product            TypeName  Inches  Ram          OS  Weight  \
# 5     Acer       58            Notebook    15.6    4  Windows 10    2.10
# 6    Apple      300           Ultrabook    15.4   16    Mac OS X    2.04
# 7    Apple      301           Ultrabook    13.3    8       macOS    1.34
# 8     Asus      608           Ultrabook    14.0   16  Windows 10    1.30
# 9     Acer      430           Ultrabook    14.0    8  Windows 10    1.60
# 10      HP       50            Notebook    15.6    4       No OS    1.86
# 11      HP       50            Notebook    15.6    4       No OS    1.86
# 12   Apple      300           Ultrabook    15.4   16       macOS    1.83
# 13    Dell      239            Notebook    15.6    4  Windows 10    2.20
# 14   Apple      298           Ultrabook    12.0    8       macOS    0.92
# 15   Apple      300           Ultrabook    13.3    8       macOS    1.37
# 16    Dell      239            Notebook    15.6    8  Windows 10    2.20
# ...

# %%
data[data.index == 10]
# Out:
#    Company  Product  TypeName  Inches  Ram     OS  Weight  Price_euros  \
# 10      HP       50  Notebook    15.6    4  No OS    1.86        393.9
#
#       Screen  ScreenW  ...  RetinaDisplay CPU_company CPU_freq CPU_model  \
# 10  Standard     1366  ...             No       Intel      2.5        46
#
#    PrimaryStorage  SecondaryStorage  PrimaryStorageType  SecondaryStorageType  \
# 10            500                 0                 HDD                    No
#
#     GPU_company        GPU_model
# 10        Intel  HD Graphics 620
#
# [1 rows x 23 columns]

# %%
#Isolating tweo or more rows using []
#Similarly, two or more rows can be returned using the .isin() method instead of a == operator.


data[data.index.isin(range(8,41))]
# Out:
#    Company  Product            TypeName  Inches  Ram          OS  Weight  \
# 8     Asus      608           Ultrabook    14.0   16  Windows 10    1.30
# 9     Acer      430           Ultrabook    14.0    8  Windows 10    1.60
# 10      HP       50            Notebook    15.6    4       No OS    1.86
# 11      HP       50            Notebook    15.6    4       No OS    1.86
# 12   Apple      300           Ultrabook    15.4   16       macOS    1.83
# 13    Dell      239            Notebook    15.6    4  Windows 10    2.20
# 14   Apple      298           Ultrabook    12.0    8       macOS    0.92
# 15   Apple      300           Ultrabook    13.3    8       macOS    1.37
# 16    Dell      239            Notebook    15.6    8  Windows 10    2.20
# 17   Apple      300           Ultrabook    15.4   16       macOS    1.83
# 18  Lenovo      209            Notebook    15.6    8       No OS    2.20
# 19    Dell      576           Ultrabook    13.3    8  Windows 10    1.22
# ...

# %%
data.isnull().sum()
# Out:
# Company                 0
# Product                 0
# TypeName                0
# Inches                  0
# Ram                     0
# OS                      0
# Weight                  0
# Price_euros             0
# Screen                  0
# ScreenW                 0
# ScreenH                 0
# Touchscreen             0
# IPSpanel                0
# RetinaDisplay           0
# CPU_company             0
# CPU_freq                0
# CPU_model               0
# PrimaryStorage          0
# SecondaryStorage        0
# PrimaryStorageType      0
# SecondaryStorageType    0
# GPU_company             0
# GPU_model               0
# dtype: int64

# %%
status_counts = data['Company'].value_counts()
plt.figure(figsize=(20, 20))
plt.pie(status_counts, labels=status_counts.index, autopct='%1.1f%%', startangle=140)
plt.show()

# %%
sns.boxplot(x="OS", y="Screen", data=data)

plt.xlabel("OS")
plt.ylabel("Screen")
plt.show()

# %%
sns.violinplot(x="Ram", y="Price_euros", data=data)

plt.xlabel("Ram")
plt.ylabel("Price_euros")
plt.show()

# %%
corr_matrix = data.select_dtypes(include=['number']).corr()

# Create a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(corr_matrix, annot=True, cmap=sns.cubehelix_palette(as_cmap=True), linewidths=0.5)

plt.show()

# %%
sns.pairplot(data.select_dtypes(include=['number']))

plt.show()
